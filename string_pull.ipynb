# %%
raw_string_1 = '''{
	"data": {
		"topics": {
			"edges": [{
				"node": {
					"id": "46",
					"__typename": "Topic",
					"name": "Productivity",
					"slug": "productivity",
					"description": "If time is most precious, this collection of lifehacks is so so precious. Be more productive and optimize your life.",
					"imageUuid": "5e906c86-5776-4ef0-9841-2b76dea8e255",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "267",
					"__typename": "Topic",
					"name": "Developer Tools",
					"slug": "developer-tools",
					"description": "Writing code is hard. So we make software to help us write software. Whether it's a new text editor or little command line app. Dev tools are here to make your life as a developer even easier.",
					"imageUuid": "bcfb0ae5-5ebf-4557-93ff-2684a4530c17",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "352",
					"__typename": "Topic",
					"name": "Tech",
					"slug": "tech",
					"description": "Hardware or software. Invention or innovation. If someone’s pushing technology forward, you’ll find it here.",
					"imageUuid": "701fd26a-c028-48ec-a7e8-bf0f89d48e03",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "268",
					"__typename": "Topic",
					"name": "Artificial Intelligence",
					"slug": "artificial-intelligence",
					"description": "A.I. helps save us time and scale personalized services like shopping like never before. But watch out, the robots are getting smarter.",
					"imageUuid": "0418cd04-f440-4021-8cf9-56be06164b0d",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "164",
					"__typename": "Topic",
					"name": "Marketing",
					"slug": "marketing",
					"description": "Having a killer product is essential, but it's not that useful if no one knows about it. These products will help you spread the word about your new startup or project.",
					"imageUuid": "8b1810e8-5a6a-4dab-a608-655f630aeec1",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "93",
					"__typename": "Topic",
					"name": "User Experience",
					"slug": "user-experience",
					"description": "Is your product easy for people to understand and use? If you're unsure, here are some tools to find out.",
					"imageUuid": "2d51fe9e-36e3-4275-8b52-3ee0b416741d",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "44",
					"__typename": "Topic",
					"name": "Design Tools",
					"slug": "design-tools",
					"description": "Design is more than just pretty pixels (no offense, pretty pixels). It's about user experience (UX), graphic design, and so much more, often aided by tools like Photoshop, Sketch, Illustrator, and other useful tools. 🎨",
					"imageUuid": "4bb79a58-baab-4434-af76-985ca67ed467.png",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "232",
					"__typename": "Topic",
					"name": "Internet of Things",
					"slug": "internet-of-things",
					"description": "Connect everything to the internet, from your home lighting to connected espressos. Thank you for making coffee, Jarvis.",
					"imageUuid": "c23aa1a5-664d-491d-b5fd-635dfbba56ae",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "261",
					"__typename": "Topic",
					"name": "Wearables",
					"slug": "wearables",
					"description": "From dog collars to wrist watches, there's wearable technology for everything. It's now easier than ever to measure the progress of your New Years resolutions (or lack thereof). 😁",
					"imageUuid": "ac2d297c-6bed-4652-815a-342c6f3ee094",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "73",
					"__typename": "Topic",
					"name": "Home",
					"slug": "home",
					"description": "Live in the future with the latest in connected devices, furniture built for comfort, and robots. Yes, robots.",
					"imageUuid": "54f8ccb5-b3c8-419f-b7a5-1972cbbc145b",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "108",
					"__typename": "Topic",
					"name": "Analytics",
					"slug": "analytics",
					"description": "You can't (accurately) improve things you can't measure. From Mixpanel to Google Analytics, there are all kinds of tools to make sure you're on track.",
					"imageUuid": "29a622e7-881b-48ff-b5c0-cb1924600247",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "251",
					"__typename": "Topic",
					"name": "Photography",
					"slug": "photography",
					"description": "Whether you're Instagram famous or simply a photography enthusiast, there are so many apps and products to make that selfie or time-lapse sunrise even more beautiful. 📷",
					"imageUuid": "2e0fc2dc-ef8f-4d72-a40c-6ea81324bc95",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "206",
					"__typename": "Topic",
					"name": "Growth Hacking",
					"slug": "growth-hacking",
					"description": "We're all looking for the hockey stick. Here are a few things that might help, but first follow this topic NOW. #growthhacking",
					"imageUuid": "39bdc399-ad33-49a0-9c62-3f229ba8b031",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "354",
					"__typename": "Topic",
					"name": "Books",
					"slug": "books",
					"description": "There’s just nothing like a good book. Expand your knowledge or just kick back with a great adventure.",
					"imageUuid": "65334d10-36be-4e72-81a2-61b9799c1760",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "342",
					"__typename": "Topic",
					"name": "Bots",
					"slug": "bots",
					"description": "There’s a bot for just about everything, from restaurant recommendations to cat GIFs. ​Bleep bloop beep",
					"imageUuid": "caecc8f1-18c0-4c61-82b6-f451b9d1d68b",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "8",
					"__typename": "Topic",
					"name": "iPhone",
					"slug": "iphone",
					"description": "The beloved \"phone\" that changed the way we communicate, play games, and snap photos. 📱",
					"imageUuid": "0ee71650-973d-4933-a3eb-c7201950db4b",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "19",
					"__typename": "Topic",
					"name": "Mac",
					"slug": "mac",
					"description": "The legendary foundations of Apple Computers. They're easy to use and easy to love. Go ahead, hop on the 🍎 bandwagon.",
					"imageUuid": "b12e534e-e08c-479e-84a7-f6b740fafcc3",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "21",
					"__typename": "Topic",
					"name": "Web App",
					"slug": "web-app",
					"description": "You know that place with all those cat pics and GIFs? It also has some other neat stuff.",
					"imageUuid": "02cf1d95-a985-4657-a3c5-c7c31faafe8e",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "88",
					"__typename": "Topic",
					"name": "APIs",
					"slug": "apis",
					"description": "There's an API (Application Program Interface) for just about everything. Here are a few.",
					"imageUuid": "ae6b752c-3334-4b30-9c1e-91ad46427619",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "353",
					"__typename": "Topic",
					"name": "Games",
					"slug": "games",
					"description": "Find something new and exciting to play at home or on the go. Work can wait. Have some fun.",
					"imageUuid": "13464a83-6701-4257-b810-c4c84979e3fc",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}],
			"pageInfo": {
				"endCursor": "MjA=",
				"hasNextPage": true,
				"__typename": "PageInfo"
			},
			"__typename": "TopicConnection"
		}
	}
}'''

# %%
raw_string_2 = '''{
	"data": {
		"newsletter": {
			"id": "8443",
			"__typename": "Newsletter",
			"slug": "8443-3d-printing-isn-t-where-we-thought-it-would-be",
			"date": "2021-05-02",
			"subject": "3D printing isn’t where we thought it would be",
			"primarySection": {
				"imageUuid": "a57e63a5-9efc-4940-8a17-8ac7630af255.gif",
				"__typename": "NewsletterSection"
			}
		},
		"viewer": {
			"__typename": "Viewer",
			"id": null,
			"hasNewsletterSubscription": false,
			"canClaimAwsCredits": false,
			"email": null
		},
		"stories": {
			"edges": [{
				"node": {
					"id": "3433",
					"__typename": "AnthologiesStory",
					"slug": "the-tools-i-use-to-get-to-inbox-zero",
					"title": "The tools I use to get to Inbox Zero",
					"headerImageUuid": "5aad1dcc-2b9b-4790-8a90-53673f94d1fd.png"
				},
				"__typename": "AnthologiesStoryEdge"
			}, {
				"node": {
					"id": "3499",
					"__typename": "AnthologiesStory",
					"slug": "suhail-doshi-s-new-company-mighty-is-a-faster-browser-streamed-from-the-cloud",
					"title": "Suhail Doshi’s new company, Mighty, is a faster browser streamed from the cloud",
					"headerImageUuid": "54d4503e-09f1-4b8b-b66e-c0106ab21eba.gif"
				},
				"__typename": "AnthologiesStoryEdge"
			}, {
				"node": {
					"id": "3466",
					"__typename": "AnthologiesStory",
					"slug": "what-s-stopping-you-write-it-down",
					"title": "What’s stopping you? Write it down.",
					"headerImageUuid": "85c251dc-83d4-48d3-9e03-502d66054c01.jpeg"
				},
				"__typename": "AnthologiesStoryEdge"
			}],
			"__typename": "AnthologiesStoryConnection"
		}
	}
}'''

# %%
raw_string_3 = '''{
	"data": {
		"topics": {
			"edges": [{
				"node": {
					"id": "48",
					"__typename": "Topic",
					"name": "Task Management",
					"slug": "task-management",
					"description": "Managing your time is hard without a plan. Make a list, check it twice, see which tasks are easy and nice. ✔︎",
					"imageUuid": "28310986-f159-4906-a604-7fa891df0c70",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "104",
					"__typename": "Topic",
					"name": "Social Media Tools",
					"slug": "social-media-tools",
					"description": "#GrowthHack your Twitter following and become a social media ninja with these tools. But first, follow us at @ProductHunt. #teamfollowback",
					"imageUuid": "caa0dfc2-a385-45f0-a53e-2ddd2ae6f118",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "22",
					"__typename": "Topic",
					"name": "Slack",
					"slug": "slack",
					"description": "Real-time chat with everyone. Use it with your team, family, and friends.",
					"imageUuid": "769d5480-f555-460d-bc47-fc9aca70774e",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "43",
					"__typename": "Topic",
					"name": "Health and Fitness",
					"slug": "health-and-fitness",
					"description": "Losing weight? Gaining weight? There are so many resources available, from calorie counting apps to personal coaches in your pocket. 💪",
					"imageUuid": "8e1b5a69-584a-4cf1-aec7-ac79e946a1eb",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "122",
					"__typename": "Topic",
					"name": "Prototyping",
					"slug": "prototyping",
					"description": "Bring your idea to life super fast with quick and dirty wireframes, mockups, and functional prototypes. Don't worry if it's not perfect.",
					"imageUuid": "08436ba4-7b58-43ae-956e-23141ec1fbd8",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "204",
					"__typename": "Topic",
					"name": "Education",
					"slug": "education",
					"description": "Learn, do, teach. Always be learning!",
					"imageUuid": "62d1511a-6334-4bf9-96ef-8311dbee2907",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "89",
					"__typename": "Topic",
					"name": "Open Source",
					"slug": "open-source",
					"description": "Sharing is caring. Build great things together.",
					"imageUuid": "1fc0084c-d910-40b9-b4d0-e5799f0ff24c",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "276",
					"__typename": "Topic",
					"name": "Product Hunt",
					"slug": "product-hunt",
					"description": "The place to discover your next favorite thing. Hunt products, search for inspiration, or build along with us. Our community has already created a ton of great sites, extensions and apps with our API.",
					"imageUuid": "c39c11c7-2e21-450d-bec8-f262e9689b5b",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "90",
					"__typename": "Topic",
					"name": "Writing Tools",
					"slug": "writing-tools",
					"description": "Shakespeare didn't use fancy apps but we're not all Shakespeare. Here are a few things to help you write more good.",
					"imageUuid": "347d842b-5067-4ae9-b84b-117a5eb0c50a",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "2",
					"__typename": "Topic",
					"name": "Android",
					"slug": "android",
					"description": "One of the fastest growing platforms of all time, the little green bot lives in your pocket and does just about anything.",
					"imageUuid": "d3e235c7-437b-4ed1-8298-2ce04eded455",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "60",
					"__typename": "Topic",
					"name": "Messaging",
					"slug": "messaging",
					"description": "Plain text can be so boring. Find a new way to spice up your communication.",
					"imageUuid": "ab5e7c00-efec-4b95-b645-4a71d31c6473",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "34",
					"__typename": "Topic",
					"name": "Chrome Extensions",
					"slug": "chrome-extensions",
					"description": "Level up your Chrome with super browser extensions. Happy surfing. 🏄",
					"imageUuid": "06b31d2a-1647-436a-8bd5-19a19e415725",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "102",
					"__typename": "Topic",
					"name": "Facebook",
					"slug": "facebook",
					"description": "Connect and stay in touch with everyone you've ever met. Digitally.",
					"imageUuid": "6a1a808c-39c8-413b-8b26-8aae7b016d93",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "57",
					"__typename": "Topic",
					"name": "Music",
					"slug": "music",
					"description": "The sounds of the world are a click or tap away. Find new ways to listen, share and create amazing music. 🎶",
					"imageUuid": "f48a8a55-27f9-44f5-a8ac-52bd88093f4c",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "356",
					"__typename": "Topic",
					"name": "Touch Bar Apps",
					"slug": "touch-bar-apps",
					"description": "Apps built for Apple's new Touch Bar 👇",
					"imageUuid": "c74c96b5-94a5-4fce-8b39-9ec0e094d7ac",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "208",
					"__typename": "Topic",
					"name": "Venture Capital",
					"slug": "venture-capital",
					"description": "If your job is to turn pennies onto benjamins, these tools and resources might help (but sorry, Uber's seed round closed long ago).",
					"imageUuid": "12ad51dd-ec9b-4c31-a7f0-78eea2d14c12",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "30",
					"__typename": "Topic",
					"name": "Virtual Reality",
					"slug": "virtual-reality",
					"description": "Strap on an Oculus or HTC Vive, and transport to a virtual world. Virtual Reality (VR) is one of the most transformational technologies to change the way we game, travel, and “call” home.",
					"imageUuid": "fdc4c79e-7e09-4e8d-834c-fb2d3a9d8f36",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "269",
					"__typename": "Topic",
					"name": "Augmented Reality",
					"slug": "augmented-reality",
					"description": "Transforming the world, AR has the potential to change our lives.",
					"imageUuid": "526b491f-b909-4796-8e28-42192c62357c",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "266",
					"__typename": "Topic",
					"name": "Netflix",
					"slug": "netflix",
					"description": "There are all sorts of apps to \"Netflix and chill\" (in the literal sense) and improve your TV/movie streaming experience.",
					"imageUuid": "effef378-b483-447e-904a-abf36e63926f",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "272",
					"__typename": "Topic",
					"name": "GitHub",
					"slug": "github",
					"description": "Distributed version control as a service. But it's so much more than that. GitHub is where developers build, collaborate and share software.",
					"imageUuid": "60058201-2c97-4b80-bf4f-3ced91160181",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}],
			"pageInfo": {
				"endCursor": "NDA=",
				"hasNextPage": true,
				"__typename": "PageInfo"
			},
			"__typename": "TopicConnection"
		}
	}
}'''

# %%
raw_string_4 = '''{
	"data": {
		"topics": {
			"edges": [{
				"node": {
					"id": "250",
					"__typename": "Topic",
					"name": "Travel",
					"slug": "travel",
					"description": "So many places to see. From the beaches, to the mountains, explore the world and satisfy your inner wunderlust",
					"imageUuid": "0a49cae9-ccff-47f1-8998-d0f47c2e7775",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "50",
					"__typename": "Topic",
					"name": "News",
					"slug": "news",
					"description": "Stay in the know. Keep up to date. See what's going on in the world.",
					"imageUuid": "d684b65c-3fa9-471d-a90f-110569d4cdd0.png",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "39",
					"__typename": "Topic",
					"name": "Email",
					"slug": "email",
					"description": "Love it or hate it, electronic mail is a huge part of your life but fortunately there are so many apps and extensions to make it more managable. PSA: Please don't \"Reply All\" to everything. 😁",
					"imageUuid": "7b05891a-6cbc-4ef5-a2c5-ae63c79606d4",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "94",
					"__typename": "Topic",
					"name": "Fintech",
					"slug": "fintech",
					"description": "At some point we all have to pay bills, save money and pay our taxes. Here are a few things to help manage finances before your cash flies away. 💸",
					"imageUuid": "6a4b83cb-2bfa-453e-8c69-063574607b80",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "278",
					"__typename": "Topic",
					"name": "E-Commerce",
					"slug": "e-commerce",
					"description": "Now you never have to leave the comfort of your home. Discover and purchase whatever you want, whenever you want.",
					"imageUuid": "1aa939fc-89dd-49ae-9fde-d456f9a6c8d2",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "135",
					"__typename": "Topic",
					"name": "Branding",
					"slug": "branding",
					"description": "Know who you are and make sure everyone else does to.",
					"imageUuid": "69370aa3-10ad-4f17-a21e-cc997cb13e5c",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "256",
					"__typename": "Topic",
					"name": "Calendar and Scheduling",
					"slug": "calendar-and-scheduling",
					"description": "Calendar ping pong is an awful game. These apps and services can help you manage your schedule and save you a ton of time.",
					"imageUuid": "064f3dc8-6163-4ffe-80f1-c846d770f21d",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "249",
					"__typename": "Topic",
					"name": "Nomad Lifestyle",
					"slug": "nomad-lifestyle",
					"description": "Not all who wander are lost. Some travel with their home on their back, living and working in cities across the globe. 🌍 Now there are sites to help nomads meet each other, book a place to stay, and most importantly, find free WiFi.",
					"imageUuid": "16a5bde6-74dc-4ad3-9823-02e739f4819d",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "247",
					"__typename": "Topic",
					"name": "Software Engineering",
					"slug": "software-engineering",
					"description": "Software is eating the world. Even your toaster has software these days. When a group of people come together and build software. We call that software engineering.",
					"imageUuid": "30d30fef-c5a9-4991-b1e5-944e256d8641.jpeg",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "231",
					"__typename": "Topic",
					"name": "SEO Tools",
					"slug": "seo-tools",
					"description": "The first page of a Google search is so important, because, let’s face it, who actually makes it to page 2? Improve your visibility, increase your ranking and get more visitors by implementing some of these tips, tricks and tools.",
					"imageUuid": "26c37180-c3af-4a18-9035-c203b62618b0.png",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "343",
					"__typename": "Topic",
					"name": "LinkedIn",
					"slug": "linkedin",
					"description": "The most professional network of them all is more than just the website. Here's a variety of apps and hacks built on top of the platform.",
					"imageUuid": "645f1693-11c3-4dec-86f9-1377ef360c4e",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "212",
					"__typename": "Topic",
					"name": "Crypto",
					"slug": "crypto",
					"description": "Bitcoin, Litecoin, Dogecoin. Cryptocurrency has the capability to change the way we transact and so much more.",
					"imageUuid": "6a4b83cb-2bfa-453e-8c69-063574607b80",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "254",
					"__typename": "Topic",
					"name": "Coffee",
					"slug": "coffee",
					"description": "The fluid that fuels millions of caffeine-addicts. ☕️",
					"imageUuid": "14355fb8-cfd1-4a01-b2eb-2e7872a6a374",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "128",
					"__typename": "Topic",
					"name": "Email Marketing",
					"slug": "email-marketing",
					"description": "Email is still one of the stickiest channels to communicate with your users. Email better with some of these marketing tools.",
					"imageUuid": "dadb5a62-00db-4d1d-a9b2-df1a33be2756",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "72",
					"__typename": "Topic",
					"name": "Freelance",
					"slug": "freelance",
					"description": "Welcome to the gig economy! Be your own boss and create your own work destiny. But working for yourself has its challenges. Make it easier with invoicing tools, time-management apps, and coworking locators.",
					"imageUuid": "2895738d-6e46-45b4-9946-3e808102e5b8",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "105",
					"__typename": "Topic",
					"name": "GIFs",
					"slug": "gifs",
					"description": "If a picture is worth a thousand words, how much is a GIF worth? We don't know but they sure are fun.",
					"imageUuid": "19bd7b8d-090e-4c49-8c92-1d990e7e5160",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "237",
					"__typename": "Topic",
					"name": "SaaS",
					"slug": "saas",
					"description": "Software as a Service. It's software that lives in the cloud without all the annoying parts like installation or maintenance. Why do any of that when someone else will take care of it for you?",
					"imageUuid": "c2251ae6-414b-4e3a-ab26-ef25a1eb8681",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "207",
					"__typename": "Topic",
					"name": "Advertising",
					"slug": "advertising",
					"description": "We get to use so many free services thanks to advertising. Get the most out of your ad budget and earn revenue with some of these tools.",
					"imageUuid": "21d8df2e-73f3-4685-94e1-d68a1d439975",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "230",
					"__typename": "Topic",
					"name": "Crowdfunding",
					"slug": "crowdfunding",
					"description": "An idea is a good start but how do you turn it into reality or find out if other people really care? Crowdfunding might be your answer, and here are some resources that can help.",
					"imageUuid": "cf345307-bd27-4cb0-bd15-5752208bdb6f",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "351",
					"__typename": "Topic",
					"name": "iMessage Apps",
					"slug": "imessage-apps",
					"description": "New in iOS 10, apps are integrated with messaging on your iPhone to easily create and share content, add stickers, make payments, and more, without leaving the conversation. ",
					"imageUuid": "a0e1d2e2-c3f8-48a9-9b94-81ac45b792ab",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}],
			"pageInfo": {
				"endCursor": "NjA=",
				"hasNextPage": true,
				"__typename": "PageInfo"
			},
			"__typename": "TopicConnection"
		}
	}
}'''

# %%
raw_string_5 = '''{
	"data": {
		"topics": {
			"edges": [{
				"node": {
					"id": "101",
					"__typename": "Topic",
					"name": "Twitter",
					"slug": "twitter",
					"description": "Share your thoughts with the world in 140 characters... unless you're using OneShot. Tweet like a pro and explore the vast universe of Twitter apps.",
					"imageUuid": "7b22e1c8-0223-489f-81ed-5bac221c2d14",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "65",
					"__typename": "Topic",
					"name": "Spotify",
					"slug": "spotify",
					"description": "What's your favorite way to stream the best music? Set the mood with a perfect playlist or start the party bumpin with the illest bangers. 🎶",
					"imageUuid": "63cdfa9d-d1cc-4d9e-acc0-4c2007fc8f17",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "31",
					"__typename": "Topic",
					"name": "Drones",
					"slug": "drones",
					"description": "It’s a bird! It’s a plane! Nope, it's a drone. Unmanned aerial vehicles are growing in popularity, from the DGI Phantom to the autonomous Lily drone. Even Amazon may deliver T.P. from the sky soon.",
					"imageUuid": "4445980b-1d7c-4219-a9e3-ad92ca98c16c",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "203",
					"__typename": "Topic",
					"name": "Investing",
					"slug": "investing",
					"description": "Takes money to make money! Get your start here.",
					"imageUuid": "a1a090ae-b882-4fc1-9bf9-8422717c89ed",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "63",
					"__typename": "Topic",
					"name": "Instagram",
					"slug": "instagram",
					"description": "Did you know you can schedule your Instagram posts, turn your best photos into edible marshmallows, and get detailed analytics for all your pics? There are apps for that. 📷",
					"imageUuid": "6d5a1eff-3b97-41bb-bb51-13d907e14b65.png",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "280",
					"__typename": "Topic",
					"name": "Snapchat",
					"slug": "snapchat",
					"description": "The hottest \"new\" ephemeral social network used for more than just selfies. Follow ProductHuntTeam. 👻",
					"imageUuid": "f7647ae2-8d42-4153-a296-c1dd5b9ec104",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "178",
					"__typename": "Topic",
					"name": "Startup Books",
					"slug": "startup-books",
					"description": "Startups are hard. First, equip yourself with an understanding of how to do customer development, market your product, and raise venture for your company.",
					"imageUuid": "ebd16702-5135-4dc1-ba85-8a32f5a99538",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "271",
					"__typename": "Topic",
					"name": "Sketch",
					"slug": "sketch",
					"description": "An alernative to Photoshop and Illustrator often used to design today's most popular apps and sites.",
					"imageUuid": "39095508-195a-4c65-843f-30d2a70aff67",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "242",
					"__typename": "Topic",
					"name": "WordPress",
					"slug": "wordpress",
					"description": "The content management system you probably use everyday without even knowing it. WordPress powers 25% of the entire internet. That's a lot of internet.",
					"imageUuid": "bcf7971e-c327-4a5d-921d-12221d70ce52",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "130",
					"__typename": "Topic",
					"name": "A/B Testing",
					"slug": "a-b-testing",
					"description": "Optimize your on-boarding flow, test copy variations, or just experiment with different shades of blue. Every test is a learning opportunity and there are so many tools that can help.",
					"imageUuid": "f8bb806b-4a7e-480b-b2e7-6c38c0bc446e",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "179",
					"__typename": "Topic",
					"name": "Design Books",
					"slug": "design-books",
					"description": "Learn how to design memorable, beautiful experiences. Design is much more than pretty pixels.",
					"imageUuid": "94463457-5ad6-4011-9abc-6db7ea128817",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "132",
					"__typename": "Topic",
					"name": "Typography",
					"slug": "typography",
					"description": "Typography is an artform, and now there are so many to choose from (or make yourself). But please, no more Comic Sans... or  Curlz MT or Papyrus.",
					"imageUuid": "f56621a9-e6fc-46df-9c9d-50d33fe23ac0",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "341",
					"__typename": "Topic",
					"name": "Medium",
					"slug": "medium",
					"description": "All things Medium. Tools that make your writing experience better, plug into the Medium API, and more!",
					"imageUuid": "4cafc1d9-45dd-4bee-8879-bb9de1cc7b07",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "361",
					"__typename": "Topic",
					"name": "Google",
					"slug": "google",
					"description": "From search, email, and video to A.I., self-driving cars, and VR, Google does it all. Don't miss the latest products, projects, and resources from Google teams around the 🌏.",
					"imageUuid": "7bdc49c4-466b-4124-b685-d826ec9f3adb",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "64",
					"__typename": "Topic",
					"name": "Amazon",
					"slug": "amazon",
					"description": "The \"bookstore\" that sells T.P. and anything you're looking for.",
					"imageUuid": "7c47ea3a-90b3-4988-9575-896cf2ba2049",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "213",
					"__typename": "Topic",
					"name": "Text Editors",
					"slug": "text-editors",
					"description": "So many ways to write on your digital devices.",
					"imageUuid": "add4a982-bbf1-4ebc-a5ba-c1ae7d983746",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "71",
					"__typename": "Topic",
					"name": "Sales",
					"slug": "sales",
					"description": "A great product isn't much without sales. Improve your conversation and get to the close with some of these useful tools.",
					"imageUuid": "78a04b3f-028a-4d02-a341-62beca8168c5.jpeg",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "76",
					"__typename": "Topic",
					"name": "Art",
					"slug": "art",
					"description": "There are a million ways to create art and there are many tools to help get those creative juices flowing. Express yourself!",
					"imageUuid": "e7333ba8-6c6d-4ac2-8128-adb1c02207db",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "279",
					"__typename": "Topic",
					"name": "YouTube",
					"slug": "youtube",
					"description": "The place to watch cats (and everything else on the internet)📽. Here are some apps and sites to YouTube better.",
					"imageUuid": "cfce0050-13fb-4790-90cf-3badb66194d1",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "282",
					"__typename": "Topic",
					"name": "Virtual Assistants",
					"slug": "virtual-assistants",
					"description": "We could all use a personal assistant. Offload your to-do list and save time with these helpful services.",
					"imageUuid": "19de1ad2-d61c-401d-bcab-a03991fdf18c",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}],
			"pageInfo": {
				"endCursor": "ODA=",
				"hasNextPage": true,
				"__typename": "PageInfo"
			},
			"__typename": "TopicConnection"
		}
	}
}'''

# %%
raw_string_6 = '''{
	"data": {
		"topics": {
			"edges": [{
				"node": {
					"id": "283",
					"__typename": "Topic",
					"name": "reddit",
					"slug": "reddit",
					"description": "The front page of the Internet",
					"imageUuid": "c293687c-f816-47fb-9bbb-a71ffc92bd73",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "264",
					"__typename": "Topic",
					"name": "Biohacking",
					"slug": "biohacking",
					"description": "Biotechnology is a fascinating field where scientists and innovators manipulate living systems to improve the way we function.",
					"imageUuid": "c5ab3d52-2a07-41ba-af41-d08d684459c6",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "41",
					"__typename": "Topic",
					"name": "Hiring and Recruiting",
					"slug": "hiring-and-recruiting",
					"description": "Need to hire someone? Want a job? You've come to the right place.",
					"imageUuid": "78a04b3f-028a-4d02-a341-62beca8168c5.jpeg",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "209",
					"__typename": "Topic",
					"name": "Learn a Language",
					"slug": "learn-a-language",
					"description": "Parlez-vous Francais? Sprichst du Deutsch? Hablas español? If you have no idea what any of that means, this might be the right place for you.",
					"imageUuid": "83915546-9f52-4746-9374-0dd7286dfa04.png",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "100",
					"__typename": "Topic",
					"name": "Movies",
					"slug": "movies",
					"description": "There are so many apps to help you find the right flick, from horror to rom-com to horror rom-com. Browse this topic and chill. 🎥",
					"imageUuid": "975e819c-f251-4f64-97cd-ddc89ddde357",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "214",
					"__typename": "Topic",
					"name": "Photoshop",
					"slug": "photoshop",
					"description": "Reinvent the entire world, right from your desk with Adobe's Photoshop, one of the most powerful graphics editors around. 👩‍🎨",
					"imageUuid": "97974c14-c412-4858-a728-89de6cebed82",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "308",
					"__typename": "Topic",
					"name": "Maps",
					"slug": "maps",
					"description": "There's a map for that 🌎",
					"imageUuid": "0d126b36-130e-423f-a7ea-1a660344f00e",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "362",
					"__typename": "Topic",
					"name": "Apple",
					"slug": "apple",
					"description": "Every new iDevice, app, and computer from the biggest 🍎  in the world.",
					"imageUuid": "e6bd8096-2de0-433c-8880-baac0ccd62c7",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "303",
					"__typename": "Topic",
					"name": "Mac Menu Bar Apps",
					"slug": "mac-menu-bar-apps",
					"description": "Tiny little apps that do magical things and live in your OS X menu bar. Collect 'em all!",
					"imageUuid": "4b58fa67-37e0-4824-b2f2-df968c8c7131",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "119",
					"__typename": "Topic",
					"name": "Payment",
					"slug": "payment",
					"description": "Pay up! Exchange money using more than just those ancient papers and hunks of metal.",
					"imageUuid": "2c8d8e59-64b9-4444-b858-d6f661a7d4fa",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "138",
					"__typename": "Topic",
					"name": "Meditation",
					"slug": "meditation",
					"description": "Technology can raise our blood pressure but it can also help cure everyday anxiousness. Take a break, clear your mind, relieve the stress. There's an app for that.",
					"imageUuid": "ac0c0786-fc36-4651-9152-4819cb161a39",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "205",
					"__typename": "Topic",
					"name": "Time Tracking",
					"slug": "time-tracking",
					"description": "Time is always escaping us. Track what you're doing so you can be more efficient with life's most precious resource.",
					"imageUuid": "96d48ff9-d311-4185-8211-74e4780a93ac",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "74",
					"__typename": "Topic",
					"name": "Fashion",
					"slug": "fashion",
					"description": "Keeping up with the trends is a job on its own. Fortunately there are a few services to help you find the right fit. 👕💍👠",
					"imageUuid": "3afb147a-4e70-412d-b7f9-4759cf0c8e34",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "349",
					"__typename": "Topic",
					"name": "Green Tech",
					"slug": "green-tech",
					"description": "Making the world a cleaner place",
					"imageUuid": "1cb42979-ae05-4827-bda4-50de94fd622b",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "85",
					"__typename": "Topic",
					"name": "Email Newsletters",
					"slug": "email-newsletters",
					"description": "Email is far from dead. In fact, it's home to some of the best content on the Internet, like the Product Hunt daily digest. 😁",
					"imageUuid": "7ea26a5c-f611-4a17-b1d8-0aab92fe52c3",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "42",
					"__typename": "Topic",
					"name": "Funny",
					"slug": "funny",
					"description": "Knock knock. Who's there? Bad Jokes, cat puns and more. Get ready to LOL right meow.",
					"imageUuid": "ef6a1bd9-305d-42a3-af42-99f8ce507684",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "346",
					"__typename": "Topic",
					"name": "Facebook Messenger",
					"slug": "facebook-messenger",
					"description": "",
					"imageUuid": "beeb2966-d52b-4791-8f97-207ec8925c49",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "125",
					"__typename": "Topic",
					"name": "Hardware",
					"slug": "hardware",
					"description": "Software may be eating the world but it's nothing without hardware.",
					"imageUuid": "df831f79-6d0c-4b5c-a834-efa5444cec92",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "18",
					"__typename": "Topic",
					"name": "Windows",
					"slug": "windows",
					"description": "The Personal Computer changed the way we live and work, created by the legendary Bill Gates with the vision to put a \"computer on every desk\".",
					"imageUuid": "d5354dbb-c4b4-4054-957d-110b3f1de730",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "123",
					"__typename": "Topic",
					"name": "Customer communication",
					"slug": "customer-communication",
					"description": "The customer is always right, right? From customer support tools to handwritten card services, there are so many ways to make your users smile. 😊",
					"imageUuid": "2978e032-d5d4-4a93-96f5-1b150085afe5",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}],
			"pageInfo": {
				"endCursor": "MTAw",
				"hasNextPage": true,
				"__typename": "PageInfo"
			},
			"__typename": "TopicConnection"
		}
	}
}'''

# %%
raw_string_7 = '''{
	"data": {
		"topics": {
			"edges": [{
				"node": {
					"id": "110",
					"__typename": "Topic",
					"name": "Robots",
					"slug": "robots",
					"description": "Sure, they might one day take over the world, but for now robots are pretty cool! Let's enjoy them while we can.",
					"imageUuid": "25f62a72-a840-4804-b0df-b897b38c7c9e",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "68",
					"__typename": "Topic",
					"name": "Video Streaming",
					"slug": "video-streaming",
					"description": "There are so many TV and movie streaming options, is cable TV really necessary? Just don't waste your entire night hunting for something to watch. 😉",
					"imageUuid": "722fb30d-e316-42f6-90a5-d38393e5daca",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "248",
					"__typename": "Topic",
					"name": "Privacy",
					"slug": "privacy",
					"description": "You don't have to wear a tinfoil hat to hide from the NSA. There are apps for that.",
					"imageUuid": "82a9b73f-6e78-4160-914d-9fd7974ad0fc.gif",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "45",
					"__typename": "Topic",
					"name": "Emoji",
					"slug": "emoji",
					"description": "Be more expressive with your communication. 😁😮😜",
					"imageUuid": "19809260-4267-4ea6-80c2-b28148472685",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "274",
					"__typename": "Topic",
					"name": "Wi-Fi",
					"slug": "wi-fi",
					"description": "A necessity these days. There are a bunch of helpful products that can help to keep you connected 24/7. (P.S. Does not play well with airplanes…yet)",
					"imageUuid": "a8ecbc67-d1d4-49bc-b118-22f310c85b46",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "131",
					"__typename": "Topic",
					"name": "Spreadsheets",
					"slug": "spreadsheets",
					"description": "Giant tables of information for your organizational pleasure. Put numbers in them. Put words in them. Put GIFs in them! It's up to you.",
					"imageUuid": "5c2b6e19-60d7-4212-a8ee-3b602a922188",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "348",
					"__typename": "Topic",
					"name": "Pokemon",
					"slug": "pokemon",
					"description": "Gotta catch 'em all",
					"imageUuid": "b99d037f-b683-4801-8dc0-8ef28a5d75fa",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "134",
					"__typename": "Topic",
					"name": "Icons",
					"slug": "icons",
					"description": "They might be small, but even the tiniest visuals matter. Make sure you've got awesome iconography for your site, app, or brand.",
					"imageUuid": "1fc0084c-d910-40b9-b4d0-e5799f0ff24c",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "357",
					"__typename": "Topic",
					"name": "Alexa Skills",
					"slug": "alexa-skills",
					"description": "🗣 Alexa, what awesome things can you do?",
					"imageUuid": "7732bad8-65de-4f27-b38e-c943b08e2b80",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "97",
					"__typename": "Topic",
					"name": "3D Printing",
					"slug": "3d-printing",
					"description": "Magically go from digital renditions to touchable prototypes. 3D printing lets you think, create and build multidimension things, from jewelry to toys to selfies (yes, really).",
					"imageUuid": "4c2907eb-9ee0-4fdb-9b7c-bb332863776a",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "227",
					"__typename": "Topic",
					"name": "Space",
					"slug": "space",
					"description": "Explore new galaxies from the comfort of a VR headset or liftoff into space through a sci-fi book. Pro tip: the answer is 42. ✨",
					"imageUuid": "6a027f20-4446-42b4-8117-4a43a1095e79",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "95",
					"__typename": "Topic",
					"name": "Public Relations",
					"slug": "public-relations",
					"description": "Getting your story to the right people can be hard, but with tools like PR in a Box and PR Stack, it's getting easier.",
					"imageUuid": "7a9925da-990f-4613-95cc-18a8a9a79dcf.png",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "176",
					"__typename": "Topic",
					"name": "Cooking",
					"slug": "cooking",
					"description": "Turn raw ingredients into delicious meals for your family and friends. It's like magic.",
					"imageUuid": "0fa195f2-19a1-472c-83b6-4a505c6689e0",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "345",
					"__typename": "Topic",
					"name": "Outdoors",
					"slug": "outdoors",
					"description": "",
					"imageUuid": "e839e3f7-2260-4c2d-be06-6ded2ce5f8f2",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "9",
					"__typename": "Topic",
					"name": "iPad",
					"slug": "ipad",
					"description": "A slab of Apple computing genius, now in multiple tablet sizes: Mini, Air, and Pro.",
					"imageUuid": "371802b7-b667-4e91-b441-b31203ea50d6",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "111",
					"__typename": "Topic",
					"name": "Sports",
					"slug": "sports",
					"description": "Whether they involve kicking, throwing, or catching, we all we all love sports. ⚽️ 🏈 🏀",
					"imageUuid": "e64fa8a8-8b00-48b7-bf7b-65a46b0a1dd4.jpeg",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "358",
					"__typename": "Topic",
					"name": "Google Home",
					"slug": "google-home",
					"description": "Ok Google! What are some of the awesome things you can do?",
					"imageUuid": "22490cdf-0b74-4879-a9fa-0b1ac40cfddc",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "275",
					"__typename": "Topic",
					"name": "On-Demand",
					"slug": "on-demand",
					"description": "Get what you want, when you want it, with a few taps. Don't lift a finger... Ok, maybe just one finger.",
					"imageUuid": "2f4600e3-8497-4576-972e-d6bfe1773430",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "355",
					"__typename": "Topic",
					"name": "Airbnb",
					"slug": "airbnb",
					"description": "Travel the world and experience a place like you live there.",
					"imageUuid": "2726a4e7-566e-4327-b9ae-3e22fdb28a1a",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "107",
					"__typename": "Topic",
					"name": "Dropbox",
					"slug": "dropbox",
					"description": "Store and have access to all of your files whenever and wherever you are.",
					"imageUuid": "334d3d24-4d9c-46ca-a857-30461400f19c",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}],
			"pageInfo": {
				"endCursor": "MTIw",
				"hasNextPage": true,
				"__typename": "PageInfo"
			},
			"__typename": "TopicConnection"
		}
	}
}'''

# %%
raw_string_8 = '''{
	"data": {
		"topics": {
			"edges": [{
				"node": {
					"id": "277",
					"__typename": "Topic",
					"name": "Delivery",
					"slug": "delivery",
					"description": "Until we have teleportation, this is your best bet for getting anything from point A to point B 📦",
					"imageUuid": "d1d10203-e0ce-4fc6-8038-0ac55f4a7730",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "13",
					"__typename": "Topic",
					"name": "Linux",
					"slug": "linux",
					"description": "For those who love to customize their OS to their own likings. Fedora, Red Hat, Ubuntu. You'll have your pick.",
					"imageUuid": "a91fe551-36e2-4642-803f-d06cbaec529b",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "152",
					"__typename": "Topic",
					"name": "Free Games",
					"slug": "free-games",
					"description": "We all love games, but we don't always have the money for them. These games will give you a ton of fun without stressing your budget.",
					"imageUuid": "ad003ea0-78cd-4726-b4f6-384128450402",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "96",
					"__typename": "Topic",
					"name": "Note",
					"slug": "note",
					"description": "Still using post-its for all those important to-do's? Try these tools instead.",
					"imageUuid": "fe5c5a34-f8f2-4f54-950d-7c0156d225b9",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "228",
					"__typename": "Topic",
					"name": "Beauty",
					"slug": "beauty",
					"description": "From skincare sticklers to fashion aficionados, we all have our ways of making ourselves look and feel beautiful. And the tools that enhance our beauty are only becoming more and more personalized. No matter how many changes you make, though, you’ve always been a cutie pie to us! 😍",
					"imageUuid": "62125aab-f62e-4d9c-9552-e71329e7853d",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "359",
					"__typename": "Topic",
					"name": "Wallpaper",
					"slug": "wallpaper",
					"description": "Beautify and decorate all your screens with everything and anything from sunsets over mountains to artsy photos of pebbles",
					"imageUuid": "01370f29-a17a-4ce4-b778-46e741dbfda4",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "146",
					"__typename": "Topic",
					"name": "Indie Games",
					"slug": "indie-games",
					"description": "So much passion and love goes into independent games. It's remarkable what can be made with a small budget and just a few people.",
					"imageUuid": "cf80072d-a7fc-4114-b2bc-b3b2f3649e5f",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "28",
					"__typename": "Topic",
					"name": "Uber",
					"slug": "uber",
					"description": "Get from A to B, the smartest way. Your private driver, on-demand.",
					"imageUuid": "61e77e5f-b65b-4153-8d72-584ef113f397",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "252",
					"__typename": "Topic",
					"name": "Meetings",
					"slug": "meetings",
					"description": "Welcome to adulthood, where meetings are unavoidable. Just make sure you're using the right tools to schedule and run productive meetings.",
					"imageUuid": "0e786f88-13eb-426c-9dc7-1f630e9379fb",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "61",
					"__typename": "Topic",
					"name": "Anonymous",
					"slug": "anonymous",
					"description": "Who are you? Who are you talking about? Does he know who she is? 👻 I don't know either.",
					"imageUuid": "7b5fe0c8-f97e-42d6-aa09-aebd09d7dfa4.jpeg",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "117",
					"__typename": "Topic",
					"name": "Backpacks",
					"slug": "backpacks",
					"description": "Causing bad posture since kindergarten, backpacks can be a pain. But they're also quite useful, whether you're rocking a stylish P.MAI bag or playful (non-ephemeral) Snapchat ghost backpack.",
					"imageUuid": "e839e3f7-2260-4c2d-be06-6ded2ce5f8f2",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "12",
					"__typename": "Topic",
					"name": "Apple Watch",
					"slug": "apple-watch",
					"description": "When you don't have enough notifications on your Phone to distract you, get them on your wrist. Apple's sexy wearable might change your life.",
					"imageUuid": "3ec254ba-1174-40cc-a8dd-3e8011f45857",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "253",
					"__typename": "Topic",
					"name": "TV",
					"slug": "tv",
					"description": "Cord-cutters have so many options today. Binge watch the latest Netflix original series or fall into the endless series of cat videos on YouTube. The biggest challenge is deciding what to watch. These apps and sites can help. 📺",
					"imageUuid": "0e1668ed-e854-4eb8-95df-a4475931d493",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "84",
					"__typename": "Topic",
					"name": "Events",
					"slug": "events",
					"description": "Planning a wedding, party, or brunch with friends? These tools will help.",
					"imageUuid": "5aeed323-9ac7-4b70-83ba-6272684c2b48",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "66",
					"__typename": "Topic",
					"name": "SoundCloud",
					"slug": "soundcloud",
					"description": "Explore the largest community of artists, bands, podcasters and music creators, and all the apps built on top of this amazing platform for sound.",
					"imageUuid": "b9136364-265a-4df7-8485-fad2313c2cc6",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "1",
					"__typename": "Topic",
					"name": "PC",
					"slug": "pc",
					"description": "",
					"imageUuid": "55f52a13-c819-406e-a3eb-82efa5681036.png",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "17",
					"__typename": "Topic",
					"name": "Kindle",
					"slug": "kindle",
					"description": "Collect and read books that won't gather dust on the handy, portable Amazon Kindle.",
					"imageUuid": "c56daf47-38ce-4f1f-a95e-a09aed69fc38",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "258",
					"__typename": "Topic",
					"name": "Transportation",
					"slug": "transportation",
					"description": "Unfortunately, we still can't teleport but at least there are apps that can help us find the most efficient route and take us there.",
					"imageUuid": "1cb42979-ae05-4827-bda4-50de94fd622b",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "159",
					"__typename": "Topic",
					"name": "Drinking",
					"slug": "drinking",
					"description": "It's 5 o'clock somewhere. Just one drink. 🍻",
					"imageUuid": "33a0c652-253d-491f-b86b-4e9ba32ee203",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "259",
					"__typename": "Topic",
					"name": "Legal",
					"slug": "legal",
					"description": "There are a host of companies and apps that are focused on streamlining the legal process. They provide everything from free legal documents, to on-demand notaries, to templates for creating your will (God forbid).",
					"imageUuid": "780c2b6f-a690-4141-b82a-9ccb0fb9c510",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}],
			"pageInfo": {
				"endCursor": "MTQw",
				"hasNextPage": true,
				"__typename": "PageInfo"
			},
			"__typename": "TopicConnection"
		}
	}
}'''

# %%
raw_string_9 = '''{
	"data": {
		"topics": {
			"edges": [{
				"node": {
					"id": "147",
					"__typename": "Topic",
					"name": "Strategy games",
					"slug": "strategy-games",
					"description": "Some of us like to turn off our brain and mash buttons. Others prefer an intellectual challenge, methodically plan each and every move. Challenge your brain with these games.",
					"imageUuid": "7605878d-c9c9-4cd7-8b77-0a22f9442758.png",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "36",
					"__typename": "Topic",
					"name": "Board Games",
					"slug": "board-games",
					"description": "Before computers and iPads, there were board games. They came in boxes and and you got friends together and played with them and it was awesome.",
					"imageUuid": "d3da58e7-5ee5-45dc-9406-a8c820b5b259",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "103",
					"__typename": "Topic",
					"name": "Dating",
					"slug": "dating",
					"description": "Find your soulmate (or maybe just a new friend) in a few swipes, taps, and emojis exchanges. 😽",
					"imageUuid": "e6cf850b-f791-40dd-b408-745f32cceaf5.gif",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "26",
					"__typename": "Topic",
					"name": "Apple TV",
					"slug": "apple-tv",
					"description": "After a long day at the office, find solitude in the vast world of TV and film on your Apple TV. Couch not included. 📺",
					"imageUuid": "722fb30d-e316-42f6-90a5-d38393e5daca",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "29",
					"__typename": "Topic",
					"name": "Telegram",
					"slug": "telegram",
					"description": "The free, multiplatform messaging app used by over 100 million people every month is home for bots for every use case. Here are some of the best integrations.",
					"imageUuid": "4df8b982-b8ac-487c-9740-1c86111ae9f1.png",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "92",
					"__typename": "Topic",
					"name": "Cars",
					"slug": "cars",
					"description": "Vroom vroom, beep beep! Turn your Sonata into a smart car with Automatic, drive safer with Navdy, or have a new whip delivered to you with Skurt. 🚗💨",
					"imageUuid": "1cb42979-ae05-4827-bda4-50de94fd622b",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "67",
					"__typename": "Topic",
					"name": "Standing Desks",
					"slug": "standing-desks",
					"description": "If the science says stand, we're going to stand 👫. From $25 to $2,500, there's a standing desk for everyone.",
					"imageUuid": "0e595733-b324-4f87-ba5c-36afa60c05b2.gif",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "217",
					"__typename": "Topic",
					"name": "Couples",
					"slug": "couples",
					"description": "Communicate and share your love in private with your boo. 😘",
					"imageUuid": "a1d1af30-5d4b-454f-9cf5-85d6490310e9",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "246",
					"__typename": "Topic",
					"name": "Emulators",
					"slug": "emulators",
					"description": "Itching to run your favorite game from your childhood? But gave up your old Atari at the family garage sale? Good thing there's an emulator for that.",
					"imageUuid": "6a27ca44-831b-49a0-a9d6-2f59e410c2aa.png",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "182",
					"__typename": "Topic",
					"name": "Science Books",
					"slug": "science-books",
					"description": "Learn more about yourself and how the world works. Bill Nye would be proud of your curiousity.",
					"imageUuid": "dff1aea9-b7e6-4ea8-964e-258661ae546b",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "78",
					"__typename": "Topic",
					"name": "Dogs",
					"slug": "dogs",
					"description": "That fuzzy 'ol pup with the tongue out is your best friend. There are lots of ways to show him your love so make sure he's got the best care to keep your canine smiling. 🐶",
					"imageUuid": "4e0495f6-fd6a-46d7-8144-c3ae96670f82.jpeg",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "82",
					"__typename": "Topic",
					"name": "Parenting",
					"slug": "parenting",
					"description": "Be knowledgeable and enjoy the wild ride of parenthood. If you need help, there are some great resources and apps for you and your family.",
					"imageUuid": "711e1015-34d0-4a65-b54c-cd43e08c678d.jpeg",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "55",
					"__typename": "Topic",
					"name": "CSM Tools",
					"slug": "csm-tools",
					"description": "There's got to be an easier way to keep people happy. Find smart ways to manage all your relationships with these helpful customer service management tools.",
					"imageUuid": "7ec5972d-89e8-4f3d-943e-598fab4a31ca",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "170",
					"__typename": "Topic",
					"name": "Charity and Giving",
					"slug": "charity-and-giving",
					"description": "There are so many ways to help others with a few taps on your phone. Donate your time or money to the homeless, disabled, and others in need of help.",
					"imageUuid": "e005ba05-88fd-4433-9e5c-cf82241d61d1",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "199",
					"__typename": "Topic",
					"name": "Pets",
					"slug": "pets",
					"description": "Your new best friend that doesn't talk back (because they're not human).",
					"imageUuid": "830a27f2-dcda-4d4c-aa03-a904116cbc17",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "124",
					"__typename": "Topic",
					"name": "Ad Blockers",
					"slug": "ad-blockers",
					"description": "Browse the web faster and get rid of those pesky popups and obnoxious ads with ad blockers for your computer and smartphone. Don't worry, we won't tell.",
					"imageUuid": "47a045e3-52ba-40da-b4ff-0e4f86929eb6",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "15",
					"__typename": "Topic",
					"name": "Safari Extensions",
					"slug": "safari-extensions",
					"description": "",
					"imageUuid": "d041157e-fa14-46fa-997c-e9a927fbadb3",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "210",
					"__typename": "Topic",
					"name": "Phone Cases",
					"slug": "phone-cases",
					"description": "There’s nothing worse than a cracked phone screen, but cases can do much more than just protect your phone. Prong powers cellphones all day long, HandL is gripless and comes with a stand, and Snoop’s Lighter case comes with -- you guessed it -- a lighter. 🔥",
					"imageUuid": "0441ab72-8b00-422f-b08d-28e37e1d4a98.jpeg",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "211",
					"__typename": "Topic",
					"name": "Batteries",
					"slug": "batteries",
					"description": "Low battery anxiety is the worst of first world problems. Here are some external batteries and products to keep your devices full charged. 🔋",
					"imageUuid": "99e0a734-129a-4152-a0f8-fec5d113a5e8",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "16",
					"__typename": "Topic",
					"name": "Firefox Extensions",
					"slug": "firefox-extensions",
					"description": "",
					"imageUuid": "0746a2f5-c883-4a43-9687-a4fde823cbc4",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}],
			"pageInfo": {
				"endCursor": "MTYw",
				"hasNextPage": true,
				"__typename": "PageInfo"
			},
			"__typename": "TopicConnection"
		}
	}
}'''

# %%
raw_string_10 = '''{
	"data": {
		"topics": {
			"edges": [{
				"node": {
					"id": "157",
					"__typename": "Topic",
					"name": "Kids",
					"slug": "kids",
					"description": "Games can be fun and educational. These games will help your child learn, grow, and have a great time.",
					"imageUuid": "502340b7-c41c-48e9-ad04-d174a8545ed1",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "150",
					"__typename": "Topic",
					"name": "Puzzle Games",
					"slug": "puzzle-games",
					"description": "Get your brain working overtime with mind-bending puzzles.",
					"imageUuid": "ad003ea0-78cd-4726-b4f6-384128450402",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "23",
					"__typename": "Topic",
					"name": "Oculus Rift",
					"slug": "oculus-rift",
					"description": "Facebook's Oculus is looking to revolutionize the way we consume media and communicate with the world, through virtual reality (VR).",
					"imageUuid": "371c74f7-111d-4b3c-a590-1992f1d6209c",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "51",
					"__typename": "Topic",
					"name": "Politics",
					"slug": "politics",
					"description": "Left wing, Right wing, Green Party, Anarchist, Tea Party... the list goes on. Get political!",
					"imageUuid": "345f4ec9-c3f6-4c45-af91-c01f5852e9ec.gif",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "27",
					"__typename": "Topic",
					"name": "Gear VR",
					"slug": "gear-vr",
					"description": "Slip into the world of virtual reality whenever you want to the Samsung Gear VR.",
					"imageUuid": "69237ed5-11fc-418d-b307-b688bfac7ce6",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "198",
					"__typename": "Topic",
					"name": "Cats",
					"slug": "cats",
					"description": "The Internet's favorite animal. MEOW! 😸",
					"imageUuid": "e9942644-2220-4e5b-ad2e-2fc89354d2bb",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "307",
					"__typename": "Topic",
					"name": "Star Wars",
					"slug": "star-wars",
					"description": "Jedi, droids, Stormtroopers, and more. Love these products you will.",
					"imageUuid": "468e1a59-e1af-4a59-8782-042db1c287c7",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "221",
					"__typename": "Topic",
					"name": "Comics and Graphic Novels",
					"slug": "comics-and-graphic-novels",
					"description": "Spiderman, Wonderwoman, Batman, and so many other superheroes have inspired our imagination since childhood. Turns out, they’ve inspired some great apps too.",
					"imageUuid": "8e92cac6-ee01-410b-a84f-5229604b206e",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "145",
					"__typename": "Topic",
					"name": "Adventure Games",
					"slug": "adventure-games",
					"description": "Like adventure but value your life? That's understandable. Fortunately, we can explore dangerous dungeons and unforgiving seas from the comfort of our home. Load up your gear and get ready for a great time.",
					"imageUuid": "5209e36d-a2ab-4267-b0fe-38aa419a7ccf",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "243",
					"__typename": "Topic",
					"name": "Squarespace",
					"slug": "squarespace",
					"description": "Build and design your own beautiful website without a line of code.",
					"imageUuid": "94eb5034-3892-4191-8f91-bed09aaecbd8",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "11",
					"__typename": "Topic",
					"name": "Card Games",
					"slug": "card-games",
					"description": "Did you know that card games used to be played IRL with laminated paper instead of on an iPad? Crazy, right?!",
					"imageUuid": "09f4ec73-c082-4527-9f66-0e5a0d279cd5",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "59",
					"__typename": "Topic",
					"name": "Sneakers and Shoes",
					"slug": "sneakers-and-shoes",
					"description": "You kind of have to wear shoes, so make sure you're rocking something in style. Do your research and choose a pair of sneakers you're proud to wear.",
					"imageUuid": "3bf594cd-e6f3-42b2-8975-9c0e225c9515.jpeg",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "80",
					"__typename": "Topic",
					"name": "Wine",
					"slug": "wine",
					"description": "You know when you wake up and you're alreadying thinking of that perfect glass of 🍷 for your evening wind down? Well, you've come to the right place.",
					"imageUuid": "f03f96ea-8dbf-473b-8c71-53395c4c7e08",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "4",
					"__typename": "Topic",
					"name": "PS4",
					"slug": "ps4",
					"description": "",
					"imageUuid": "ffeda232-a1d4-48fe-952b-531b5666feb7",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "156",
					"__typename": "Topic",
					"name": "Retro Games",
					"slug": "retro-games",
					"description": "Back in the day, games were simple and fun. Take a trip back to the good ole day with these retro titles.",
					"imageUuid": "1827a17d-084e-41f4-a1ce-cb59f02c9e90",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "175",
					"__typename": "Topic",
					"name": "Art Books",
					"slug": "art-books",
					"description": "Feast your creativity on books that delight your artistic flare. Whether you're a budding Vincent Van Gough, Banksy or just looking for that perfect book to complete your coffee table collection, there's a wealth of literature to be discovered.",
					"imageUuid": "a8f78f31-239e-44a6-a3d1-d255b346f8c1",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "148",
					"__typename": "Topic",
					"name": "Open World Games",
					"slug": "open-world-games",
					"description": "With these games, you can go wherever you want, whenever you want. Time to explore.",
					"imageUuid": "0e25b3cd-f648-415a-9678-513926f09f78.jpeg",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "87",
					"__typename": "Topic",
					"name": "Weather Apps",
					"slug": "weather-apps",
					"description": "You could look outside to see if it's raining, or you could look at your smartphone. Predict the future and plan your day with magical, fortune-telling weather apps.",
					"imageUuid": "f5564b87-e953-4488-80a0-11772b2eb424",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "137",
					"__typename": "Topic",
					"name": "Moving and Storage",
					"slug": "moving-and-storage",
					"description": "Whether you're moving across the world or cleaning out the junk under your staircase, there are so many services to help (and save your back).",
					"imageUuid": "fc7451f3-50d0-44e9-8db2-8818971bb3fa.jpeg",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "172",
					"__typename": "Topic",
					"name": "Biking",
					"slug": "biking",
					"description": "Slip on your spandex, stretch your legs, and explore these products before hopping onto your bike.",
					"imageUuid": "15a3be58-83c5-4e06-9349-74ef3db47828",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}],
			"pageInfo": {
				"endCursor": "MTgw",
				"hasNextPage": true,
				"__typename": "PageInfo"
			},
			"__typename": "TopicConnection"
		}
	}
}'''

# %%
raw_string_11 = '''{
	"data": {
		"topics": {
			"edges": [{
				"node": {
					"id": "157",
					"__typename": "Topic",
					"name": "Kids",
					"slug": "kids",
					"description": "Games can be fun and educational. These games will help your child learn, grow, and have a great time.",
					"imageUuid": "502340b7-c41c-48e9-ad04-d174a8545ed1",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "150",
					"__typename": "Topic",
					"name": "Puzzle Games",
					"slug": "puzzle-games",
					"description": "Get your brain working overtime with mind-bending puzzles.",
					"imageUuid": "ad003ea0-78cd-4726-b4f6-384128450402",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "23",
					"__typename": "Topic",
					"name": "Oculus Rift",
					"slug": "oculus-rift",
					"description": "Facebook's Oculus is looking to revolutionize the way we consume media and communicate with the world, through virtual reality (VR).",
					"imageUuid": "371c74f7-111d-4b3c-a590-1992f1d6209c",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "51",
					"__typename": "Topic",
					"name": "Politics",
					"slug": "politics",
					"description": "Left wing, Right wing, Green Party, Anarchist, Tea Party... the list goes on. Get political!",
					"imageUuid": "345f4ec9-c3f6-4c45-af91-c01f5852e9ec.gif",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "27",
					"__typename": "Topic",
					"name": "Gear VR",
					"slug": "gear-vr",
					"description": "Slip into the world of virtual reality whenever you want to the Samsung Gear VR.",
					"imageUuid": "69237ed5-11fc-418d-b307-b688bfac7ce6",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "198",
					"__typename": "Topic",
					"name": "Cats",
					"slug": "cats",
					"description": "The Internet's favorite animal. MEOW! 😸",
					"imageUuid": "e9942644-2220-4e5b-ad2e-2fc89354d2bb",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "307",
					"__typename": "Topic",
					"name": "Star Wars",
					"slug": "star-wars",
					"description": "Jedi, droids, Stormtroopers, and more. Love these products you will.",
					"imageUuid": "468e1a59-e1af-4a59-8782-042db1c287c7",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "221",
					"__typename": "Topic",
					"name": "Comics and Graphic Novels",
					"slug": "comics-and-graphic-novels",
					"description": "Spiderman, Wonderwoman, Batman, and so many other superheroes have inspired our imagination since childhood. Turns out, they’ve inspired some great apps too.",
					"imageUuid": "8e92cac6-ee01-410b-a84f-5229604b206e",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "145",
					"__typename": "Topic",
					"name": "Adventure Games",
					"slug": "adventure-games",
					"description": "Like adventure but value your life? That's understandable. Fortunately, we can explore dangerous dungeons and unforgiving seas from the comfort of our home. Load up your gear and get ready for a great time.",
					"imageUuid": "5209e36d-a2ab-4267-b0fe-38aa419a7ccf",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "243",
					"__typename": "Topic",
					"name": "Squarespace",
					"slug": "squarespace",
					"description": "Build and design your own beautiful website without a line of code.",
					"imageUuid": "94eb5034-3892-4191-8f91-bed09aaecbd8",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "11",
					"__typename": "Topic",
					"name": "Card Games",
					"slug": "card-games",
					"description": "Did you know that card games used to be played IRL with laminated paper instead of on an iPad? Crazy, right?!",
					"imageUuid": "09f4ec73-c082-4527-9f66-0e5a0d279cd5",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "59",
					"__typename": "Topic",
					"name": "Sneakers and Shoes",
					"slug": "sneakers-and-shoes",
					"description": "You kind of have to wear shoes, so make sure you're rocking something in style. Do your research and choose a pair of sneakers you're proud to wear.",
					"imageUuid": "3bf594cd-e6f3-42b2-8975-9c0e225c9515.jpeg",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "80",
					"__typename": "Topic",
					"name": "Wine",
					"slug": "wine",
					"description": "You know when you wake up and you're alreadying thinking of that perfect glass of 🍷 for your evening wind down? Well, you've come to the right place.",
					"imageUuid": "f03f96ea-8dbf-473b-8c71-53395c4c7e08",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "4",
					"__typename": "Topic",
					"name": "PS4",
					"slug": "ps4",
					"description": "",
					"imageUuid": "ffeda232-a1d4-48fe-952b-531b5666feb7",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "156",
					"__typename": "Topic",
					"name": "Retro Games",
					"slug": "retro-games",
					"description": "Back in the day, games were simple and fun. Take a trip back to the good ole day with these retro titles.",
					"imageUuid": "1827a17d-084e-41f4-a1ce-cb59f02c9e90",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "175",
					"__typename": "Topic",
					"name": "Art Books",
					"slug": "art-books",
					"description": "Feast your creativity on books that delight your artistic flare. Whether you're a budding Vincent Van Gough, Banksy or just looking for that perfect book to complete your coffee table collection, there's a wealth of literature to be discovered.",
					"imageUuid": "a8f78f31-239e-44a6-a3d1-d255b346f8c1",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "148",
					"__typename": "Topic",
					"name": "Open World Games",
					"slug": "open-world-games",
					"description": "With these games, you can go wherever you want, whenever you want. Time to explore.",
					"imageUuid": "0e25b3cd-f648-415a-9678-513926f09f78.jpeg",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "87",
					"__typename": "Topic",
					"name": "Weather Apps",
					"slug": "weather-apps",
					"description": "You could look outside to see if it's raining, or you could look at your smartphone. Predict the future and plan your day with magical, fortune-telling weather apps.",
					"imageUuid": "f5564b87-e953-4488-80a0-11772b2eb424",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "137",
					"__typename": "Topic",
					"name": "Moving and Storage",
					"slug": "moving-and-storage",
					"description": "Whether you're moving across the world or cleaning out the junk under your staircase, there are so many services to help (and save your back).",
					"imageUuid": "fc7451f3-50d0-44e9-8db2-8818971bb3fa.jpeg",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}, {
				"node": {
					"id": "172",
					"__typename": "Topic",
					"name": "Biking",
					"slug": "biking",
					"description": "Slip on your spandex, stretch your legs, and explore these products before hopping onto your bike.",
					"imageUuid": "15a3be58-83c5-4e06-9349-74ef3db47828",
					"isFollowed": false
				},
				"__typename": "TopicEdge"
			}],
			"pageInfo": {
				"endCursor": "MTgw",
				"hasNextPage": true,
				"__typename": "PageInfo"
			},
			"__typename": "TopicConnection"
		}
	}
}'''

# %%
raw_full_str = raw_string_1 + raw_string_2 + raw_string_3 + raw_string_4 + raw_string_5 + raw_string_6 + raw_string_7 + raw_string_8 + raw_string_9 + raw_string_10 + raw_string_11

# %%
full_str = raw_full_str.replace('"', '')

# %%
data = ''' "Productivity"
 "Developer Tools"
 "Tech"
 "Artificial Intelligence"
 "Marketing"
 "User Experience"
 "Design Tools"
 "Internet of Things"
 "Wearables"
 "Home"
 "Analytics"
 "Photography"
 "Growth Hacking"
 "Books"
 "Bots"
 "iPhone"
 "Mac"
 "Web App"
 "APIs"
 "Games"
 "Task Management"
 "Social Media Tools"
 "Slack"
 "Health and Fitness"
 "Prototyping"
 "Education"
 "Open Source"
 "Product Hunt"
 "Writing Tools"
 "Android"
 "Messaging"
 "Chrome Extensions"
 "Facebook"
 "Music"
 "Touch Bar Apps"
 "Venture Capital"
 "Virtual Reality"
 "Augmented Reality"
 "Netflix"
 "GitHub"
 "Travel"
 "News"
 "Email"
 "Fintech"
 "E-Commerce"
 "Branding"
 "Calendar and Scheduling"
 "Nomad Lifestyle"
 "Software Engineering"
 "SEO Tools"
 "LinkedIn"
 "Crypto"
 "Coffee"
 "Email Marketing"
 "Freelance"
 "GIFs"
 "SaaS"
 "Advertising"
 "Crowdfunding"
 "iMessage Apps"
 "Twitter"
 "Spotify"
 "Drones"
 "Investing"
 "Instagram"
 "Snapchat"
 "Startup Books"
 "Sketch"
 "WordPress"
 "A/B Testing"
 "Design Books"
 "Typography"
 "Medium"
 "Google"
 "Amazon"
 "Text Editors"
 "Sales"
 "Art"
 "YouTube"
 "Virtual Assistants"
 "reddit"
 "Biohacking"
 "Hiring and Recruiting"
 "Learn a Language"
 "Movies"
 "Photoshop"
 "Maps"
 "Apple"
 "Mac Menu Bar Apps"
 "Payment"
 "Meditation"
 "Time Tracking"
 "Fashion"
 "Green Tech"
 "Email Newsletters"
 "Funny"
 "Facebook Messenger"
 "Hardware"
 "Windows"
 "Customer communication"
 "Robots"
 "Video Streaming"
 "Privacy"
 "Emoji"
 "Wi-Fi"
 "Spreadsheets"
 "Pokemon"
 "Icons"
 "Alexa Skills"
 "3D Printing"
 "Space"
 "Public Relations"
 "Cooking"
 "Outdoors"
 "iPad"
 "Sports"
 "Google Home"
 "On-Demand"
 "Airbnb"
 "Dropbox"
 "Delivery"
 "Linux"
 "Free Games"
 "Note"
 "Beauty"
 "Wallpaper"
 "Indie Games"
 "Uber"
 "Meetings"
 "Anonymous"
 "Backpacks"
 "Apple Watch"
 "TV"
 "Events"
 "SoundCloud"
 "PC"
 "Kindle"
 "Transportation"
 "Drinking"
 "Legal"
 "Strategy games"
 "Board Games"
 "Dating"
 "Apple TV"
 "Telegram"
 "Cars"
 "Standing Desks"
 "Couples"
 "Emulators"
 "Science Books"
 "Dogs"
 "Parenting"
 "CSM Tools"
 "Charity and Giving"
 "Pets"
 "Ad Blockers"
 "Safari Extensions"
 "Phone Cases"
 "Batteries"
 "Firefox Extensions"
 "Kids"
 "Puzzle Games"
 "Oculus Rift"
 "Politics"
 "Gear VR"
 "Cats"
 "Star Wars"
 "Comics and Graphic Novels"
 "Adventure Games"
 "Squarespace"
 "Card Games"
 "Sneakers and Shoes"
 "Wine"
 "PS4"
 "Retro Games"
 "Art Books"
 "Open World Games"
 "Weather Apps"
 "Moving and Storage"
 "Biking"
 "Kids"
 "Puzzle Games"
 "Oculus Rift"
 "Politics"
 "Gear VR"
 "Cats"
 "Star Wars"
 "Comics and Graphic Novels"
 "Adventure Games"
 "Squarespace"
 "Card Games"
 "Sneakers and Shoes"
 "Wine"
 "PS4"
 "Retro Games"
 "Art Books"
 "Open World Games"
 "Weather Apps"
 "Moving and Storage"
 "Biking"'''

# %%
# data.replace('"', ',')[2:].replace('\n ,', ' ')

# %%
# no_quote = raw_string.replace('"', '')

# %%
# no_quote

# %%
curr_str = "Productivity, Developer Tools, Tech, Artificial Intelligence, Marketing, User Experience, Design Tools, Internet of Things, Wearables, Home, Analytics, Photography, Growth Hacking, Books, Bots, iPhone, Mac, Web App, APIs, Games, Task Management, Social Media Tools, Slack, Health and Fitness, Prototyping, Education, Open Source, Product Hunt, Writing Tools, Android, Messaging, Chrome Extensions, Facebook, Music, Touch Bar Apps, Venture Capital, Virtual Reality, Augmented Reality, Netflix, GitHub, Travel, News, Email, Fintech, E-Commerce, Branding, Calendar and Scheduling, Nomad Lifestyle, Software Engineering, SEO Tools, LinkedIn, Crypto, Coffee, Email Marketing, Freelance, GIFs, SaaS, Advertising, Crowdfunding, iMessage Apps, Twitter, Spotify, Drones, Investing, Instagram, Snapchat, Startup Books, Sketch, WordPress, A/B Testing, Design Books, Typography, Medium, Google, Amazon, Text Editors, Sales, Art, YouTube, Virtual Assistants, reddit, Biohacking, Hiring and Recruiting, Learn a Language, Movies, Photoshop, Maps, Apple, Mac Menu Bar Apps, Payment, Meditation, Time Tracking, Fashion, Green Tech, Email Newsletters, Funny, Facebook Messenger, Hardware, Windows, Customer communication, Robots, Video Streaming, Privacy, Emoji, Wi-Fi, Spreadsheets, Pokemon, Icons, Alexa Skills, 3D Printing, Space, Public Relations, Cooking, Outdoors, iPad, Sports, Google Home, On-Demand, Airbnb, Dropbox, Delivery, Linux, Free Games, Note, Beauty, Wallpaper, Indie Games, Uber, Meetings, Anonymous, Backpacks, Apple Watch, TV, Events, SoundCloud, PC, Kindle, Transportation, Drinking, Legal, Strategy games, Board Games, Dating, Apple TV, Telegram, Cars, Standing Desks, Couples, Emulators, Science Books, Dogs, Parenting, CSM Tools, Charity and Giving, Pets, Ad Blockers, Safari Extensions, Phone Cases, Batteries, Firefox Extensions, Kids, Puzzle Games, Oculus Rift, Politics, Gear VR, Cats, Star Wars, Comics and Graphic Novels, Adventure Games, Squarespace, Card Games, Sneakers and Shoes, Wine, PS4, Retro Games, Art Books, Open World Games, Weather Apps, Moving and Storage, Biking, Kids, Puzzle Games, Oculus Rift, Politics, Gear VR, Cats, Star Wars, Comics and Graphic Novels, Adventure Games, Squarespace, Card Games, Sneakers and Shoes, Wine, PS4, Retro Games, Art Books, Open World Games, Weather Apps, Moving and Storage, Biking, Startup Lessons, Action Games, Kewelry, History Books, Cooking Books, Crafting Games, ARKit, Soccer, Custom Keyboards, Celebrities, Money, Growth Hacks, Crime, Medtech, Maker Tools, Blockstack, Social Impact, No-code, Remote Work Tools, Audio and Voice, FemTech, Diversity and Inclusion"

# %%
# curr_str

# %% [markdown]
# ---------

# %% [markdown]
# # Github Topics

# %%
with open('interests.txt', 'r') as file:
    data = file.read().replace('\n', '')

# %%
data
# Out:
# '<html lang="en"><head><meta property="og:title" content="Lunchclub"><meta property="og:type" content="website"><meta property="og:description" content="Professional connections reimagined."><meta property="og:url" content="https://lunchclub.com"><meta property="og:image" content="https://lunchclub.com/img/og-image2.png"><meta name="twitter:card" content="summary_large_image"><meta name="twitter:image" content="https://lunchclub.com/img/og-image2.png"><meta charset="utf-8"><meta name="viewport" content="width=device-width,initial-scale=1"><meta name="theme-color" content="#000000"><meta http-equiv="Cache-Control" content="no-cache, no-store, must-revalidate"><meta http-equiv="Pragma" content="no-cache"><meta http-equiv="Expires" content="0"><meta name="description" content="Lunchclub is an AI superconnector that makes introductions for 1:1 video meetings to advance your career"><meta name="keywords" content="connection,meeting,introduction,networking,expand,professional,app,software"
# ...

# %%
sample = '''

Animals and pets – cute critter photos and memes
Architecture – Some attainable inspirations and some total eye candy
Art – Wall art, drawings, how tos
Cars and motorcycles – Hotrods, antiques, and car shows
Celebrities – Mainly shots from movies and tabloids
DIY and crafts – Painting, sewing, crafts of all kinds!
Design – Home style ideas, drawings, design inspiration, graphics
Education – Resources and ideas for kids, parents, and teachers
Entertainment – Party planning, movies, books, tv
Food and drink – Recipes, recipes, and more recipes!
Gardening – How to grow anything
Geek – A place to share all those things that are so uncool they’re cool – superheroes, nerd humor, etc. 🙂
Hair and beauty – Hair and makeup
Health and fitness – Exercise and weight loss
History – Funny, artistic, and curious photos of old landmarks and cultural history
Holidays and events – Holidays, decorations, celebrations
Home decor – DIY Home decor, home decor inspiration
Humor – From clever to cheesy and a little PG-13, gifs and memes aplenty
Illustrations and posters – Paintings, posters, designs, drawings – total eye candy
Kids and parenting – Projects, learning tools, activities, crafts, parenting tips
Men’s fashion – Tips and products for the well-dressed man. Learn to tie a tie, match your socks, roll up your sleeves 🙂
Outdoors – Outdoor design, landscaping, and gardenscapes
Photography – Amateur and artistic photos plus helpful how tos
Products – Mainly product photos
Quotes – Inspirational quotes and poetry
Science and nature – Science experiments, learning resources, and astounding (and sometimes odd) nature photography
Sports – Sports memes and workouts
Tattoos – Inspiration for your next tattoo – in the form of tattoos, designs, and photos
Technology – Privacy protection, shortcuts and productivity hacks, coding tips, and cool products
Travel – Travel tips, destinations, and gorgeous photography
Weddings – Wedding dresses, etiquette, planning tips, invitations, jewelry
Women’s Fashion – Current trends, fashion to buy, how-tos
'''

# %%
splt = sample.split('\n')#[1:]
# splt = data.split('Link--primary">')


for elem in splt:
    nw = elem.split('– ')
#     nw = elem#.split('</p>')#[0].split('</button>')
    print(nw[0])
#     print(nw[0][0]
# Out:
# Animals and pets
# Architecture
# Art
# Cars and motorcycles
# Celebrities
# DIY and crafts
# Design
# Education
# Entertainment
# Food and drink
# Gardening
# Geek
# Hair and beauty
# Health and fitness
# History
# Holidays and events
# Home decor
# Humor
# Illustrations and posters
# Kids and parenting
# Men’s fashion
# Outdoors
# Photography
# Products
# Quotes
# Science and nature
# Sports
# Tattoos
# Technology
# Travel
# Weddings
# Women’s Fashion

# %%
splt[1].split('</p>')[0]
# Out:
# 'Software-defined networking'

# %%
topics = '''Animals and pets 
Architecture 
Art 
Cars and motorcycles 
Celebrities 
DIY and crafts 
Design 
Education 
Entertainment 
Food and drink 
Gardening 
Geek 
Hair and beauty 
Health and fitness 
History 
Holidays and events 
Home decor 
Humor 
Illustrations and posters 
Kids and parenting 
Men’s fashion 
Outdoors 
Photography 
Products 
Quotes 
Science and nature 
Sports 
Tattoos 
Technology 
Travel 
Weddings 
Women’s Fashion 
'''

# %%
topics.replace(' \n',', ' )
# Out:
# 'Animals and pets, Architecture, Art, Cars and motorcycles, Celebrities, DIY and crafts, Design, Education, Entertainment, Food and drink, Gardening, Geek, Hair and beauty, Health and fitness, History, Holidays and events, Home decor, Humor, Illustrations and posters, Kids and parenting, Men’s fashion, Outdoors, Photography, Products, Quotes, Science and nature, Sports, Tattoos, Technology, Travel, Weddings, Women’s Fashion, '

# %% [markdown]
# # Outputs (Topics)

# %%
githubTopics = '''3D, Ajax, Algorithm, Amp, Android, Angular, Ansible, API, Arduino, ASP.NET, Atom, Awesome Lists, Amazon Web Services, Azure, Babel, Bash, Bitcoin, Bootstrap, Bot, C, Chrome, Chrome extension, Command line interface, Clojure, Code quality, Code review, Compiler, Continuous integration, COVID-19, C++, Cryptocurrency, Crystal, C#, CSS, Data structures, Data visualization, Database, Deep learning, Dependency management, Deployment, Django, Docker, Documentation, .NET, Electron, Elixir, Emacs, Ember, Emoji, Emulator, ES6, ESLint, Ethereum, Express, Firebase, Firefox, Flask, Font, Framework, Front end, Game engine, Git, GitHub API, Go, Google, Gradle, GraphQL, Gulp, Hacktoberfest, Haskell, Homebrew, Homebridge, HTML, HTTP, Icon font, iOS, IPFS, Java, JavaScript, Jekyll, jQuery, JSON, The Julia Language, Jupyter Notebook, Koa, Kotlin, Kubernetes, Laravel, LaTeX, Library, Linux, Localization, Lua, Machine learning, macOS, Markdown, Mastodon, Material design, MATLAB, Maven, Minecraft, Mobile, Monero, MongoDB, Mongoose, Monitoring, MvvmCross, MySQL, NativeScript, Nim, Natural language processing, Node.js, NoSQL, npm, Objective-C, OpenGL, Operating system, P2P, Package manager, Parsing, Perl, Phaser, PHP, PICO-8, Pixel Art, PostgreSQL, Project management, Publishing, PWA, Python, Qt, R, Rails, Raspberry Pi, Ratchet, React, React Native, ReactiveUI, Redux, REST API, Ruby, Rust, Sass, Scala, scikit-learn, Software-defined networking, Security, Server, Serverless, Shell, Sketch, SpaceVim, Spring Boot, SQL, Storybook, Support, Swift, Symfony, Telegram, Tensorflow, Terminal, Terraform, Testing, Twitter, Typescript, Ubuntu, Unity, Unreal Engine, Vagrant, Vim, Virtual Reality, Vue.js, Wagtail, Web Components, Web app, Webpack, Windows, WordPlate, WordPress, Xamarin, XML'''

# %%
lunchclubTopics = '''Angel investing, Entrepreneurship, Healthcare, Education, Marketing, Sales, Venture capital, Fintech, entertainment, Consulting, E-commerce, Media, Retail, Investment banking, Real Estate, AI, Biohacking, Crypto, Machine learning, Product design, Programming languages, Quant finance, VR/AR, Product management, Robotics, Data science, Life sciences, Visual design, Social impact, Diversity and inclusion, Travel, Hiking, Photography, Fitness, Food, Music, Sports, Film, Writing, Reading, Sustainability, Concerts, Electronic music, Cinematography, Dinner parties, Video games, Poker, Fishing, Skiing, Fashion, Cooking, Running, Wellness, Parenting'''

# %%
pinterestTopics = '''Animals and pets, Architecture, Art, Cars and motorcycles, Celebrities, DIY and crafts, Design, Education, Entertainment, Food and drink, Gardening, Geek, Hair and beauty, Health and fitness, History, Holidays and events, Home decor, Humor, Illustrations and posters, Kids and parenting, Men’s fashion, Outdoors, Photography, Products, Quotes, Science and nature, Sports, Tattoos, Technology, Travel, Weddings, Women’s Fashion'''

# %%
producthuntTopics = '''Productivity, Developer Tools, Tech, Artificial Intelligence, Marketing, User Experience, Design Tools, Internet of Things, Wearables, Home, Analytics, Photography, Growth Hacking, Books, Bots, iPhone, Mac, Web App, APIs, Games, Task Management, Social Media Tools, Slack, Health and Fitness, Prototyping, Education, Open Source, Product Hunt, Writing Tools, Android, Messaging, Chrome Extensions, Facebook, Music, Touch Bar Apps, Venture Capital, Virtual Reality, Augmented Reality, Netflix, GitHub, Travel, News, Email, Fintech, E-Commerce, Branding, Calendar and Scheduling, Nomad Lifestyle, Software Engineering, SEO Tools, LinkedIn, Crypto, Coffee, Email Marketing, Freelance, GIFs, SaaS, Advertising, Crowdfunding, iMessage Apps, Twitter, Spotify, Drones, Investing, Instagram, Snapchat, Startup Books, Sketch, WordPress, A/B Testing, Design Books, Typography, Medium, Google, Amazon, Text Editors, Sales, Art, YouTube, Virtual Assistants, reddit, Biohacking, Hiring and Recruiting, Learn a Language, Movies, Photoshop, Maps, Apple, Mac Menu Bar Apps, Payment, Meditation, Time Tracking, Fashion, Green Tech, Email Newsletters, Funny, Facebook Messenger, Hardware, Windows, Customer communication, Robots, Video Streaming, Privacy, Emoji, Wi-Fi, Spreadsheets, Pokemon, Icons, Alexa Skills, 3D Printing, Space, Public Relations, Cooking, Outdoors, iPad, Sports, Google Home, On-Demand, Airbnb, Dropbox, Delivery, Linux, Free Games, Note, Beauty, Wallpaper, Indie Games, Uber, Meetings, Anonymous, Backpacks, Apple Watch, TV, Events, SoundCloud, PC, Kindle, Transportation, Drinking, Legal, Strategy games, Board Games, Dating, Apple TV, Telegram, Cars, Standing Desks, Couples, Emulators, Science Books, Dogs, Parenting, CSM Tools, Charity and Giving, Pets, Ad Blockers, Safari Extensions, Phone Cases, Batteries, Firefox Extensions, Kids, Puzzle Games, Oculus Rift, Politics, Gear VR, Cats, Star Wars, Comics and Graphic Novels, Adventure Games, Squarespace, Card Games, Sneakers and Shoes, Wine, PS4, Retro Games, Art Books, Open World Games, Weather Apps, Moving and Storage, Biking, Kids, Puzzle Games, Oculus Rift, Politics, Gear VR, Cats, Star Wars, Comics and Graphic Novels, Adventure Games, Squarespace, Card Games, Sneakers and Shoes, Wine, PS4, Retro Games, Art Books, Open World Games, Weather Apps, Moving and Storage, Biking, Startup Lessons, Action Games, Kewelry, History Books, Cooking Books, Crafting Games, ARKit, Soccer, Custom Keyboards, Celebrities, Money, Growth Hacks, Crime, Medtech, Maker Tools, Blockstack, Social Impact, No-code, Remote Work Tools, Audio and Voice, FemTech, Diversity and Inclusion'''
